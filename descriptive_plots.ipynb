# %%
import pandas as pd
import numpy as np
import matplotlib as plt
% matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('df.csv')

# %%
df.head()
# Out:
#    track_id   track_title track_genre_top  audio_features_acousticness  \
# 0         2          Food         Hip-Hop                     0.416675
# 1         3  Electric Ave         Hip-Hop                     0.374408
# 2         5    This World         Hip-Hop                     0.043567
# 3       134  Street Music         Hip-Hop                     0.452217
# 4       139      CandyAss            Folk                     0.106550
#
#    audio_features_danceability  audio_features_energy  \
# 0                     0.675894               0.634476
# 1                     0.528643               0.817461
# 2                     0.745566               0.701470
# 3                     0.513238               0.560410
# 4                     0.260911               0.607067
#
#    audio_features_instrumentalness  audio_features_liveness  \
# 0                         0.010628                 0.177647
# 1                         0.001851                 0.105880
# ...

# %%
df.track_genre_top.value_counts().plot(kind='bar')

# %%
sns.boxplot(x="track_genre_top", y="audio_features_acousticness", data=df)

# %%
sns.violinplot(x="track_genre_top", y="audio_features_acousticness", data=df)

# %%
sns.violinplot(x="track_genre_top", y="audio_features_acousticness", data=df, bw=.1, scale="count")
